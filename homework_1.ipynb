# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
import os

# %%
repos = requests.get('https://api.github.com/user/repos', auth=('AlisaTsv', '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'))

# %%
repos.json()
# Out:
# [{'id': 382904158,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODI5MDQxNTg=',
#   'name': 'gb_mysql',
#   'full_name': 'AlisaTsv/gb_mysql',
#   'private': False,
#   'owner': {'login': 'AlisaTsv',
#    'id': 84089860,
#    'node_id': 'MDQ6VXNlcjg0MDg5ODYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84089860?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AlisaTsv',
#    'html_url': 'https://github.com/AlisaTsv',
#    'followers_url': 'https://api.github.com/users/AlisaTsv/followers',
#    'following_url': 'https://api.github.com/users/AlisaTsv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/AlisaTsv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/AlisaTsv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/AlisaTsv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/AlisaTsv/orgs',
#    'repos_url': 'https://api.github.com/users/AlisaTsv/repos',
# ...
