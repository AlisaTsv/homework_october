# %%
import requests
import pandas as pd

# %%
number_of_pages = 10

job_title = ["'Data Analyst' and 'data scientist'"]
for job in job_title:
    data=[]
    for i in range(number_of_pages):
        url = 'https://api.hh.ru/vacancies'
        par = {'text': job, 'area':'113','per_page':'10', 'page':i}
        r = requests.get(url, params=par)
        e=r.json()
        data.append(e)
        vacancy_details = data[0]['items'][0].keys()
        df = pd.DataFrame(columns= list(vacancy_details))
        ind = 0
        for i in range(len(data)):
            for j in range(len(data[i]['items'])):
                df.loc[ind] = data[i]['items'][j]
                ind+=1

# %%
df
# Out:
#           id premium                                           name  \
# 0   48929537   False                  Data Analyst / Data Scientist
# 1   49113776   False        Data Scientist / Data Analyst (DS Team)
# 2   48939262    True                          Data Scientist в Сбер
# 3   45191074   False                                 Data Scientist
# 4   48276976   False               Data scientist / Product analyst
# ..       ...     ...                                            ...
# 95  48944837   False              Middle data scientist (Логистика)
# 96  43852997   False  Data Scientist, Поиск / Товарные рекомендации
# 97  48926505   False                                 Data Scientist
# 98  48161435   False               Data scientist (розничные риски)
# 99  48926507   False                                 Data Scientist
#
#                                            department has_test  \
# 0                                                None    False
# 1                                                None    False
# 2   {'id': '3529-3529-data', 'name': 'Сбер. Data S...    False
# 3                                                None    False
# 4                                                None    False
# ..                                                ...      ...
# 95  {'id': 'ozonru-2180-logistic', 'name': 'Ozon Л...    False
# 96  {'id': 'ozonru-2180-dev', 'name': 'Ozon Информ...    False
# 97                                               None    False
# 98                                               None    False
# 99                                               None    False
#
#    response_letter_required  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 95                    False
# 96                    False
# 97                    False
# 98                    False
# 99                    False
#
#                                                  area  \
# 0   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 2   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4   {'id': '1', 'name': 'Москва', 'url': 'https://...
# ..                                                ...
# 95  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 96  {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 97  {'id': '88', 'name': 'Казань', 'url': 'https:/...
# 98  {'id': '88', 'name': 'Казань', 'url': 'https:/...
# 99  {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
#
#                                                salary  \
# 0                                                None
# 1   {'from': 200000, 'to': None, 'currency': 'RUR'...
# 2                                                None
# 3   {'from': None, 'to': 300000, 'currency': 'RUR'...
# 4   {'from': 200000, 'to': None, 'currency': 'RUR'...
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                   type  \
# 0   {'id': 'open', 'name': 'Открытая'}
# 1   {'id': 'open', 'name': 'Открытая'}
# 2   {'id': 'open', 'name': 'Открытая'}
# 3   {'id': 'open', 'name': 'Открытая'}
# 4   {'id': 'open', 'name': 'Открытая'}
# ..                                 ...
# 95  {'id': 'open', 'name': 'Открытая'}
# 96  {'id': 'open', 'name': 'Открытая'}
# 97  {'id': 'open', 'name': 'Открытая'}
# 98  {'id': 'open', 'name': 'Открытая'}
# 99  {'id': 'open', 'name': 'Открытая'}
#
#                                               address  ...  \
# 0   {'city': 'Москва', 'street': 'Большая Семеновс...  ...
# 1   {'city': 'Санкт-Петербург', 'street': 'Заставс...  ...
# 2                                                None  ...
# 3                                                None  ...
# 4   {'city': 'Москва', 'street': 'Нижняя Красносел...  ...
# ..                                                ...  ...
# 95  {'city': 'Москва', 'street': 'Пресненская набе...  ...
# 96  {'city': 'Санкт-Петербург', 'street': 'Херсонс...  ...
# 97                                               None  ...
# 98                                               None  ...
# 99                                               None  ...
#
#                      alternate_url relations  \
# 0   https://hh.ru/vacancy/48929537        []
# 1   https://hh.ru/vacancy/49113776        []
# 2   https://hh.ru/vacancy/48939262        []
# 3   https://hh.ru/vacancy/45191074        []
# 4   https://hh.ru/vacancy/48276976        []
# ..                             ...       ...
# 95  https://hh.ru/vacancy/48944837        []
# 96  https://hh.ru/vacancy/43852997        []
# 97  https://hh.ru/vacancy/48926505        []
# 98  https://hh.ru/vacancy/48161435        []
# 99  https://hh.ru/vacancy/48926507        []
#
#                                              employer  \
# 0   {'id': '1870134', 'name': 'Национальное Бюро И...
# 1   {'id': '789662', 'name': 'Semrush', 'url': 'ht...
# 2   {'id': '3529', 'name': 'Сбербанк', 'url': 'htt...
# 3   {'id': '2324020', 'name': 'Точка', 'url': 'htt...
# 4   {'id': '2652595', 'name': 'Bip.ru', 'url': 'ht...
# ..                                                ...
# 95  {'id': '2180', 'name': 'Ozon', 'url': 'https:/...
# 96  {'id': '2180', 'name': 'Ozon', 'url': 'https:/...
# 97  {'id': '2575', 'name': 'Бэнкс Софт Системс', '...
# 98  {'id': '47939', 'name': 'Ак Барс Банк', 'url':...
# 99  {'id': '2575', 'name': 'Бэнкс Софт Системс', '...
#
#                                               snippet contacts  \
# 0   {'requirement': 'Существенным преимуществом бу...     None
# 1   {'requirement': 'Опыт работы датасайнтистом ил...     None
# 2   {'requirement': 'Computer vision.', 'responsib...     None
# 3   {'requirement': 'Есть опыт работы с методами м...     None
# 4   {'requirement': 'Опыт работы <highlighttext>ан...     None
# ..                                                ...      ...
# 95  {'requirement': 'Высшее образование. Опыт реше...     None
# 96  {'requirement': 'Писать runtime движок на Gola...     None
# 97  {'requirement': 'Опыт работы с анализом данных...     None
# 98  {'requirement': 'Математическое, экономико-мат...     None
# 99  {'requirement': 'Опыт работы с анализом данных...     None
#
#                                         schedule working_days  \
# 0       {'id': 'fullDay', 'name': 'Полный день'}           []
# 1   {'id': 'remote', 'name': 'Удаленная работа'}           []
# 2       {'id': 'fullDay', 'name': 'Полный день'}           []
# 3       {'id': 'fullDay', 'name': 'Полный день'}           []
# 4   {'id': 'remote', 'name': 'Удаленная работа'}           []
# ..                                           ...          ...
# 95      {'id': 'fullDay', 'name': 'Полный день'}           []
# 96  {'id': 'remote', 'name': 'Удаленная работа'}           []
# 97      {'id': 'fullDay', 'name': 'Полный день'}           []
# 98  {'id': 'remote', 'name': 'Удаленная работа'}           []
# 99      {'id': 'fullDay', 'name': 'Полный день'}           []
#
#    working_time_intervals working_time_modes accept_temporary
# 0                      []                 []            False
# 1                      []                 []            False
# 2                      []                 []            False
# 3                      []                 []            False
# 4                      []                 []            False
# ..                    ...                ...              ...
# 95                     []                 []            False
# 96                     []                 []            False
# 97                     []                 []            False
# 98                     []                 []            False
# 99                     []                 []            False
#
# [100 rows x 28 columns]

# %%
from bs4 import BeautifulSoup

url = 'https://api.hh.ru/vacancies'
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup)
# Out:
# {"items":[{"id":"48219835","premium":false,"name":"Менеджер по продажам (строительный крепеж)","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"88","name":"Казань","url":"https://api.hh.ru/areas/88"},"salary":{"from":80000,"to":null,"currency":"RUR","gross":false},"type":{"id":"open","name":"Открытая"},"address":null,"response_url":null,"sort_point_distance":null,"published_at":"2021-10-19T10:12:32+0300","created_at":"2021-10-19T10:12:32+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=48219835","insider_interview":null,"url":"https://api.hh.ru/vacancies/48219835?host=hh.ru","alternate_url":"https://hh.ru/vacancy/48219835","relations":[],"employer":{"id":"1060821","name":"Рост Развитие Решение","url":"https://api.hh.ru/employers/1060821","alternate_url":"https://hh.ru/employer/1060821","logo_urls":{"90":"https://hhcdn.ru/employer-logo/874868.jpeg","240":"https://hhcdn.ru/employer-logo/874869.jpeg","original":"https://hhcdn.ru/employer-logo-original/85446.jpg"},"vacancies_url":"https://api.hh.ru/vacancies?employer_id=1060821","trusted":true},"snippet":{"requirement":"Опыт в продажах приветствуется. Грамотная речь. Активность. Коммуникабельность.","responsibility":"Привлечение новых клиентов. Выезды к клиентам с целью проведения переговоров. Заключение договоров. Контроль оплаты."},"contacts":null,"schedule":{"id":"fullDay","name":"Полный день"},"working_days":[],"working_time_intervals":[],"working_time_modes":[],"accept_temporary":false},{"id":"49153137","premium":false,"name":"Менеджер по продажам ТНП (сегмент Хорека)","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"Москва","url":"https://api.hh.ru/areas/1"},"salary":{"from":80000,"to":150000,"currency":"RUR","gross":false},"type":{"id":"open","name":"Открытая"},"address":{"city":null,"street":null,"building":null,"description":null,"lat":null,"lng":null,"raw":"Долгопрудный, Промышленный проезд, 10","metro":null,"metro_stations":[],"id":"214325"},"response_url":null,"sort_point_distance":null,"published_at":"2021-10-26T14:22:31+0300","created_at":"2021-10-26T14:22:31+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=49153137","insider_interview":null,"url":"https://api.hh.ru/vacancies/49153137?host=hh.ru","alternate_url":"https://hh.ru/vacancy/49153137","relations":[],"employer":{"id":"15779","name":"Мистерия, промышленно-торговая группа","url":"https://api.hh.ru/employers/15779","alternate_url":"https://hh.ru/employer/15779","logo_urls":{"original":"https://hhcdn.ru/employer-logo-original/228759.gif","90":"https://hhcdn.ru/employer-logo/312854.png","240":"https://hhcdn.ru/employer-logo/385711.png"},"vacancies_url":"https://api.hh.ru/vacancies?employer_id=15779","trusted":true},"snippet":{"requirement":"Желателен опыт работы в 1С. Желателен опыт работы в CRM (amo / bitrix и т.п.). Образование: высшее - желательно, но...","responsibility":"Ведение личной воронки продаж (фиксация информации о клиенте и своих действий в карточках клиентов, переход карточек клиентов по этапам воронки). "},"contacts":null,"schedule":{"id":"fullDay","name":"Полный день"},"working_days":[],"working_time_intervals":[],"working_time_modes":[],"accept_temporary":false},{"id":"48615636","premium":false,"name":"Продавец-консультант (Большой Гостиный двор)","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"2","name":"Санкт-Петербург","url":"https://api.hh.ru/areas/2"},"salary":{"from":60000,"to":100000,"currency":"RUR","gross":false},"type":{"id":"open","name":"Открытая"},"address":{"city":"Санкт-Петербург","street":"3 линия","building":"метро Гостиный двор","description":null,"lat":59.934069,"lng":30.332765,"raw":"Санкт-Петербург, 3 линия, метро Гостиный двор","metro":{"station_name":"Гостиный двор","line_name":"Невско-Василеостровская","station_id":"16.229","line_id":"16","lat":59.933933,"lng":30.33341 ...

# %%
# Out:
# None
